# %% [markdown]
# # Mini RAG Chatbot
#
# ## Objective
#
# Build a Retrieval-Augmented Generation (RAG) chatbot that can answer questions from a PDF document.
#
# ## RAG Pipeline
#
# PDF → Text Extraction → Text Chunking → Embeddings → Vector Database → Semantic Search → Context Retrieval → LLM → Final Answer

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.12/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pypdf
# Out:
# Requirement already satisfied: pypdf in ./venv/lib/python3.12/site-packages (6.16.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in ./venv/lib/python3.12/site-packages (1.3.17)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in ./venv/lib/python3.12/site-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in ./venv/lib/python3.12/site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.12/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in ./venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in ./venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in ./venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in ./venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in ./venv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in ./venv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in ./venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# PDF reader
from pypdf import PdfReader

# Text splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Gemini embeddings and chat model
from langchain_google_genai import (
    GoogleGenerativeAIEmbeddings,
    ChatGoogleGenerativeAI
)

# FAISS vector database
from langchain_community.vectorstores import FAISS

# Operating system utilities
import os

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!
# /tmp/ipykernel_62377/3306648623.py:14: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS

# %%
# Path to the new Machine Learning PDF

pdf_path = "sample_data/ch1_murphy.pdf"

print("PDF path:", pdf_path)
# Out:
# PDF path: sample_data/ch1_murphy.pdf

# %%
# Load the PDF
reader = PdfReader(pdf_path)

# Count the number of pages
num_pages = len(reader.pages)

print("PDF loaded successfully!")
print("Number of pages:", num_pages)
# Out:
# Ignoring wrong pointing object 150 0 (offset 0)
# Ignoring wrong pointing object 154 0 (offset 0)
# Ignoring wrong pointing object 196 0 (offset 0)
# Ignoring wrong pointing object 226 0 (offset 0)
# Ignoring wrong pointing object 256 0 (offset 0)
# Ignoring wrong pointing object 260 0 (offset 0)
# Ignoring wrong pointing object 277 0 (offset 0)
# PDF loaded successfully!
# Number of pages: 26

# %%
# Create an empty string to store the complete PDF text
text = ""

# Loop through every page in the PDF
for page in reader.pages:
    
    # Extract text from the current page
    page_text = page.extract_text()
    
    # Add the extracted text
    if page_text:
        text += page_text + "\n"

# Display the total number of characters
print("Total characters extracted:", len(text))
# Out:
# Total characters extracted: 58510

# %%
# Display the first 2000 characters
print(text[:2000])
# Out:
# ’achine —earning
# q ﬀrobabilistic ﬀerspective
# –evin ﬀW ’urphy
# ﬄhe ’yﬄ ﬀress
# sambridgeU ’assachusetts
# —ondonU ungland
# 1 Introduction
# pmp Machine learningy what and why?
# We are drowning in information and starving for knowledgeW — zohn “aisbittW
# We are entering the era of big data W vor exampleU there are about a trillion web pages ak one
# hour of video is uploaded to Y ouﬄ ube every secondU amounting to aZ years of content every
# daybk the genomes of aZZZs of peopleU each of which has a length of 3.8 × 109 base pairsU have
# been sequenced by various labsk Walmart handles more than a’ transactions per hour and has
# databases containing more than bWe petabytes P 2.5 × 1015R of information Psukier bZaZRk and so
# onW
# ﬄhis deluge of data calls for automated methods of data analysisU which is what machine
# learning providesW yn particularU we deﬁne machine learning as a set of methods that can
# automatically detect patterns in dataU and then use the uncovered patterns to predict future
# dataU or to perform other kinds of decision making under uncertainty Psuch as planning how to
# collect more dataIRW
# ﬄhis books adopts the view that the best way to solve such problems is to use the tools
# of probability theoryW ﬀrobability theory can be applied to any problem involving uncertaintyW
# yn machine learningU uncertainty comes in many formsj what is the best prediction about the
# future given some past datao what is the best model to explain some datao what measurement
# should y perform nexto etcW ﬄhe probabilistic approach to machine learning is closely related to
# the ﬁeld of statisticsU but di￿ers slightly in terms of its emphasis and terminology cW
# We will describe a wide variety of probabilistic modelsU suitable for a wide variety of data and
# tasksW We will also describe a wide variety of algorithms for learning and using such modelsW
# ﬄhe goal is not to develop a cook book of ad hoc techiquesU but instead to present a uniﬁed
# view of the ﬁeld through the lens of probabilistic modeling and i

# %%
# Select the first 10 pages for our mini RAG project
# This keeps the number of embedding API requests small.

sample_text = ""

for page in reader.pages[:10]:
    page_text = page.extract_text()

    if page_text:
        sample_text += page_text + "\n"

print("Characters in selected pages:", len(sample_text))
# Out:
# Characters in selected pages: 22369

# %%
# Split the new PDF into chunks

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=200
)

chunks = text_splitter.split_text(text)

print("Number of chunks:", len(chunks))
# Out:
# Number of chunks: 46

# %%
# Create the Gemini embedding model

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

print("Gemini embedding model initialized successfully!")
# Out:
# Gemini embedding model initialized successfully!

# %%
# Create the FAISS vector database using the smaller chunk set

vector_store = FAISS.from_texts(
    chunks,
    embedding=embeddings
)

print("FAISS vector database created successfully!")
# Out:
# FAISS vector database created successfully!

# %%
# Define a test question
question = "What is machine learning?"

print("Question:", question)
# Out:
# Question: What is machine learning?

# %%
# Search the FAISS database for the 3 most relevant chunks

retrieved_docs = vector_store.similarity_search(
    question,
    k=3
)

# Display the retrieved chunks

for i, doc in enumerate(retrieved_docs):
    print(f"\n--- Retrieved Chunk {i + 1} ---")
    print(doc.page_content)
# Out:
# --- Retrieved Chunk 1 ---
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
# most methods assume that yi is a categorical or nominal variable from some ﬁnite setU
# yi ∈{ 1,...,C } Psuch as male or femaleRU or that yi is a realVvalued scalar Psuch as income
# levelRW When yi is categoricalU the problem is known as classiﬁcation or pattern recognitionU
# and when yi is realVvaluedU the problem is known as regressionW qnother variantU known as
# ordinal regressionU occurs where label space Y has some natural orderingU such as grades q–vW
# ﬄhe second main type of machine learning is the descriptive or unsupervised learning
# approachW xere we are only given inputsU D = {xi}N
# i=1U and the goal is to ﬁnd “interesting
# patterns” in the dataW ﬄhis is sometimes called knowledge discovery W ﬄhis is a much less
# wellVdeﬁned problemU since we are not told what kinds of patterns to look forU and there is no
# obvious error metric to use Punlike supervised learningU where we can compare our prediction
# of y for a given x to the observed valueRW
# ﬄhere is a third type of machine learningU known as reinforcement learning U which is
# somewhat less commonly usedW ﬄhis is useful for learning how to act or behave when given
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
#
# --- Retrieved Chunk 2 ---
# yt should be notedU howeverU that even when one has an apparently massive data setU the
# e￿ective number of data points for certain cases of interest might be quite smallW yn factU data
# across a variety of domains exhibits a property known as the long tail U which means that a
# few things PeWgWU wordsR are very commonU but most things are quite rare Psee ﬃection bWdWg for
# detailsRW vor exampleU bZM of woogle searches each day have never been seen before dW ﬄhis
# means that the core statistical issues that we discuss in this bookU concerning generalizing from
# relatively small samples sizesU are still very relevant even in the big data eraW
# pmpmp T ypes of machine learning
# ’achine learning is usually divided into two main typesW yn the predictive or supervised
# learning approachU the goal is to learn a mapping from inputs x to outputs yU given a labeled
# set of inputVoutput pairs D = {(xi,y i)}N
# i=1W xere D is called the training set U and N is the
# number of training examplesW
# yn the simplest settingU each training input xi is a DVdimensional vector of numbersU repV
# resentingU sayU the height and weight of a personW ﬄhese are called featuresU attributes or
# covariatesW yn generalU howeverU xi could be a complex structured objectU such as an imageU a
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
#
# --- Retrieved Chunk 3 ---
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
# in ﬃection eWgU which is the basis of ﬂ—W ﬃee eWgWU P–aelbling et alW aiifk ﬃutton and rarto aiihk
# ﬂussell and “orvig bZaZk ﬃzepesvari bZaZk Wiering and van ”tterlo bZabR for more information
# on ﬂ—W
# dW
# http://certifiedknowledge.org/blog/are-search-queries-becoming-even-more-unique-statistic
# s-from-google W
# 1.2. Supervised learning c
# PaR
#  PbR
# Figure pmp —eftj ﬃome labeled training examples of colored shapesU along with c unlabeled test casesW
# ﬂightj ﬂepresenting the training data as an N × D design matrixW ﬂow i represents the feature vector xiW
# ﬄhe last column is the labelU yi ∈{ 0, 1}W rased on a ﬁgure by —eslie –aelblingW
# pmq Supervised learning
# We begin our investigation of machine learning by discussing supervised learningU which is the
# form of ’— most widely used in practiceW
# pmqmp Classiﬁcation
# yn this sectionU we discuss classiﬁcationW xere the goal is to learn a mapping from inputs x
# to outputs yU where y ∈{ 1,...,C }U with C being the number of classesW yf C =2 U this is
# called binary classiﬁcation Pin which case we often assume y ∈{ 0, 1}Rk if C> 2U this is called
# multiclass classiﬁcation W yf the class labels are not mutually exclusive PeWgWU somebody may be
# classiﬁed as tall and strongRU we call it multillabel classiﬁcation U but this is best viewed as

# %%
# Initialize the Gemini language model
# This model will generate the final answer
# using the context retrieved from FAISS.

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0
)

print("Gemini LLM initialized successfully!")
# Out:
# Gemini LLM initialized successfully!

# %%
# Test the Gemini LLM

response = llm.invoke(
    "Explain machine learning in one simple sentence."
)

print(response.content)
# Out:
# /home/nineleaps/mini-rag-chatbot/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': 'Machine learning is the process of teaching computers to learn from data and experience so they can make smart decisions on their own.', 'extras': {'signature': '...'}}]

# %%
# User's question
question = "What is machine learning?"

print("Question:", question)
# Out:
# Question: What is machine learning?

# %%
# Retrieve the 3 most relevant chunks from the vector database

retrieved_docs = vector_store.similarity_search(
    question,
    k=3
)

# Display the retrieved chunks

for i, doc in enumerate(retrieved_docs):
    print(f"\n--- Retrieved Chunk {i + 1} ---")
    print(doc.page_content)
# Out:
# --- Retrieved Chunk 1 ---
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
# most methods assume that yi is a categorical or nominal variable from some ﬁnite setU
# yi ∈{ 1,...,C } Psuch as male or femaleRU or that yi is a realVvalued scalar Psuch as income
# levelRW When yi is categoricalU the problem is known as classiﬁcation or pattern recognitionU
# and when yi is realVvaluedU the problem is known as regressionW qnother variantU known as
# ordinal regressionU occurs where label space Y has some natural orderingU such as grades q–vW
# ﬄhe second main type of machine learning is the descriptive or unsupervised learning
# approachW xere we are only given inputsU D = {xi}N
# i=1U and the goal is to ﬁnd “interesting
# patterns” in the dataW ﬄhis is sometimes called knowledge discovery W ﬄhis is a much less
# wellVdeﬁned problemU since we are not told what kinds of patterns to look forU and there is no
# obvious error metric to use Punlike supervised learningU where we can compare our prediction
# of y for a given x to the observed valueRW
# ﬄhere is a third type of machine learningU known as reinforcement learning U which is
# somewhat less commonly usedW ﬄhis is useful for learning how to act or behave when given
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
#
# --- Retrieved Chunk 2 ---
# yt should be notedU howeverU that even when one has an apparently massive data setU the
# e￿ective number of data points for certain cases of interest might be quite smallW yn factU data
# across a variety of domains exhibits a property known as the long tail U which means that a
# few things PeWgWU wordsR are very commonU but most things are quite rare Psee ﬃection bWdWg for
# detailsRW vor exampleU bZM of woogle searches each day have never been seen before dW ﬄhis
# means that the core statistical issues that we discuss in this bookU concerning generalizing from
# relatively small samples sizesU are still very relevant even in the big data eraW
# pmpmp T ypes of machine learning
# ’achine learning is usually divided into two main typesW yn the predictive or supervised
# learning approachU the goal is to learn a mapping from inputs x to outputs yU given a labeled
# set of inputVoutput pairs D = {(xi,y i)}N
# i=1W xere D is called the training set U and N is the
# number of training examplesW
# yn the simplest settingU each training input xi is a DVdimensional vector of numbersU repV
# resentingU sayU the height and weight of a personW ﬄhese are called featuresU attributes or
# covariatesW yn generalU howeverU xi could be a complex structured objectU such as an imageU a
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
#
# --- Retrieved Chunk 3 ---
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
# in ﬃection eWgU which is the basis of ﬂ—W ﬃee eWgWU P–aelbling et alW aiifk ﬃutton and rarto aiihk
# ﬂussell and “orvig bZaZk ﬃzepesvari bZaZk Wiering and van ”tterlo bZabR for more information
# on ﬂ—W
# dW
# http://certifiedknowledge.org/blog/are-search-queries-becoming-even-more-unique-statistic
# s-from-google W
# 1.2. Supervised learning c
# PaR
#  PbR
# Figure pmp —eftj ﬃome labeled training examples of colored shapesU along with c unlabeled test casesW
# ﬂightj ﬂepresenting the training data as an N × D design matrixW ﬂow i represents the feature vector xiW
# ﬄhe last column is the labelU yi ∈{ 0, 1}W rased on a ﬁgure by —eslie –aelblingW
# pmq Supervised learning
# We begin our investigation of machine learning by discussing supervised learningU which is the
# form of ’— most widely used in practiceW
# pmqmp Classiﬁcation
# yn this sectionU we discuss classiﬁcationW xere the goal is to learn a mapping from inputs x
# to outputs yU where y ∈{ 1,...,C }U with C being the number of classesW yf C =2 U this is
# called binary classiﬁcation Pin which case we often assume y ∈{ 0, 1}Rk if C> 2U this is called
# multiclass classiﬁcation W yf the class labels are not mutually exclusive PeWgWU somebody may be
# classiﬁed as tall and strongRU we call it multillabel classiﬁcation U but this is best viewed as

# %%
# Combine the retrieved chunks into a single context

context = "\n\n".join(
    doc.page_content for doc in retrieved_docs
)

print("Retrieved context:")
print(context)
# Out:
# Retrieved context:
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
# most methods assume that yi is a categorical or nominal variable from some ﬁnite setU
# yi ∈{ 1,...,C } Psuch as male or femaleRU or that yi is a realVvalued scalar Psuch as income
# levelRW When yi is categoricalU the problem is known as classiﬁcation or pattern recognitionU
# and when yi is realVvaluedU the problem is known as regressionW qnother variantU known as
# ordinal regressionU occurs where label space Y has some natural orderingU such as grades q–vW
# ﬄhe second main type of machine learning is the descriptive or unsupervised learning
# approachW xere we are only given inputsU D = {xi}N
# i=1U and the goal is to ﬁnd “interesting
# patterns” in the dataW ﬄhis is sometimes called knowledge discovery W ﬄhis is a much less
# wellVdeﬁned problemU since we are not told what kinds of patterns to look forU and there is no
# obvious error metric to use Punlike supervised learningU where we can compare our prediction
# of y for a given x to the observed valueRW
# ﬄhere is a third type of machine learningU known as reinforcement learning U which is
# somewhat less commonly usedW ﬄhis is useful for learning how to act or behave when given
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
#
# yt should be notedU howeverU that even when one has an apparently massive data setU the
# e￿ective number of data points for certain cases of interest might be quite smallW yn factU data
# across a variety of domains exhibits a property known as the long tail U which means that a
# few things PeWgWU wordsR are very commonU but most things are quite rare Psee ﬃection bWdWg for
# detailsRW vor exampleU bZM of woogle searches each day have never been seen before dW ﬄhis
# means that the core statistical issues that we discuss in this bookU concerning generalizing from
# relatively small samples sizesU are still very relevant even in the big data eraW
# pmpmp T ypes of machine learning
# ’achine learning is usually divided into two main typesW yn the predictive or supervised
# learning approachU the goal is to learn a mapping from inputs x to outputs yU given a labeled
# set of inputVoutput pairs D = {(xi,y i)}N
# i=1W xere D is called the training set U and N is the
# number of training examplesW
# yn the simplest settingU each training input xi is a DVdimensional vector of numbersU repV
# resentingU sayU the height and weight of a personW ﬄhese are called featuresU attributes or
# covariatesW yn generalU howeverU xi could be a complex structured objectU such as an imageU a
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
#
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
# in ﬃection eWgU which is the basis of ﬂ—W ﬃee eWgWU P–aelbling et alW aiifk ﬃutton and rarto aiihk
# ﬂussell and “orvig bZaZk ﬃzepesvari bZaZk Wiering and van ”tterlo bZabR for more information
# on ﬂ—W
# dW
# http://certifiedknowledge.org/blog/are-search-queries-becoming-even-more-unique-statistic
# s-from-google W
# 1.2. Supervised learning c
# PaR
#  PbR
# Figure pmp —eftj ﬃome labeled training examples of colored shapesU along with c unlabeled test casesW
# ﬂightj ﬂepresenting the training data as an N × D design matrixW ﬂow i represents the feature vector xiW
# ﬄhe last column is the labelU yi ∈{ 0, 1}W rased on a ﬁgure by —eslie –aelblingW
# pmq Supervised learning
# We begin our investigation of machine learning by discussing supervised learningU which is the
# form of ’— most widely used in practiceW
# pmqmp Classiﬁcation
# yn this sectionU we discuss classiﬁcationW xere the goal is to learn a mapping from inputs x
# to outputs yU where y ∈{ 1,...,C }U with C being the number of classesW yf C =2 U this is
# called binary classiﬁcation Pin which case we often assume y ∈{ 0, 1}Rk if C> 2U this is called
# multiclass classiﬁcation W yf the class labels are not mutually exclusive PeWgWU somebody may be
# classiﬁed as tall and strongRU we call it multillabel classiﬁcation U but this is best viewed as

# %%
# Create the RAG prompt

prompt = f"""
You are a helpful Machine Learning assistant.

Answer the user's question using ONLY the information
provided in the context below.

If the answer cannot be found in the context, say:
"I could not find the answer in the provided document."

Context:
{context}

Question:

{question}

Answer:
"""

print(prompt)
# Out:
# You are a helpful Machine Learning assistant.
#
# Answer the user's question using ONLY the information
# provided in the context below.
#
# If the answer cannot be found in the context, say:
# "I could not find the answer in the provided document."
#
# Context:
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
# most methods assume that yi is a categorical or nominal variable from some ﬁnite setU
# yi ∈{ 1,...,C } Psuch as male or femaleRU or that yi is a realVvalued scalar Psuch as income
# levelRW When yi is categoricalU the problem is known as classiﬁcation or pattern recognitionU
# and when yi is realVvaluedU the problem is known as regressionW qnother variantU known as
# ordinal regressionU occurs where label space Y has some natural orderingU such as grades q–vW
# ﬄhe second main type of machine learning is the descriptive or unsupervised learning
# approachW xere we are only given inputsU D = {xi}N
# i=1U and the goal is to ﬁnd “interesting
# patterns” in the dataW ﬄhis is sometimes called knowledge discovery W ﬄhis is a much less
# wellVdeﬁned problemU since we are not told what kinds of patterns to look forU and there is no
# obvious error metric to use Punlike supervised learningU where we can compare our prediction
# of y for a given x to the observed valueRW
# ﬄhere is a third type of machine learningU known as reinforcement learning U which is
# somewhat less commonly usedW ﬄhis is useful for learning how to act or behave when given
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
#
# yt should be notedU howeverU that even when one has an apparently massive data setU the
# e￿ective number of data points for certain cases of interest might be quite smallW yn factU data
# across a variety of domains exhibits a property known as the long tail U which means that a
# few things PeWgWU wordsR are very commonU but most things are quite rare Psee ﬃection bWdWg for
# detailsRW vor exampleU bZM of woogle searches each day have never been seen before dW ﬄhis
# means that the core statistical issues that we discuss in this bookU concerning generalizing from
# relatively small samples sizesU are still very relevant even in the big data eraW
# pmpmp T ypes of machine learning
# ’achine learning is usually divided into two main typesW yn the predictive or supervised
# learning approachU the goal is to learn a mapping from inputs x to outputs yU given a labeled
# set of inputVoutput pairs D = {(xi,y i)}N
# i=1W xere D is called the training set U and N is the
# number of training examplesW
# yn the simplest settingU each training input xi is a DVdimensional vector of numbersU repV
# resentingU sayU the height and weight of a personW ﬄhese are called featuresU attributes or
# covariatesW yn generalU howeverU xi could be a complex structured objectU such as an imageU a
# sentenceU an email messageU a time seriesU a molecular shapeU a graphU etcW
# ﬃimilarly the form of the output or response variable can in principle be anythingU but
#
# occasional reward or punishment signalsW Pvor exampleU consider how a baby learns to walkWR
# UnfortunatelyU ﬂ— is beyond the scope of this bookU although we do discuss decision theory
# in ﬃection eWgU which is the basis of ﬂ—W ﬃee eWgWU P–aelbling et alW aiifk ﬃutton and rarto aiihk
# ﬂussell and “orvig bZaZk ﬃzepesvari bZaZk Wiering and van ”tterlo bZabR for more information
# on ﬂ—W
# dW
# http://certifiedknowledge.org/blog/are-search-queries-becoming-even-more-unique-statistic
# s-from-google W
# 1.2. Supervised learning c
# PaR
#  PbR
# Figure pmp —eftj ﬃome labeled training examples of colored shapesU along with c unlabeled test casesW
# ﬂightj ﬂepresenting the training data as an N × D design matrixW ﬂow i represents the feature vector xiW
# ﬄhe last column is the labelU yi ∈{ 0, 1}W rased on a ﬁgure by —eslie –aelblingW
# pmq Supervised learning
# We begin our investigation of machine learning by discussing supervised learningU which is the
# form of ’— most widely used in practiceW
# pmqmp Classiﬁcation
# yn this sectionU we discuss classiﬁcationW xere the goal is to learn a mapping from inputs x
# to outputs yU where y ∈{ 1,...,C }U with C being the number of classesW yf C =2 U this is
# called binary classiﬁcation Pin which case we often assume y ∈{ 0, 1}Rk if C> 2U this is called
# multiclass classiﬁcation W yf the class labels are not mutually exclusive PeWgWU somebody may be
# classiﬁed as tall and strongRU we call it multillabel classiﬁcation U but this is best viewed as
#
# Question:
#
# What is machine learning?
#
# Answer:

# %%
# Send the RAG prompt to Gemini

response = llm.invoke(prompt)

# Display only the text answer
print("Answer:")
print(response.text)
# Out:
# /home/nineleaps/mini-rag-chatbot/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Answer:
# I could not find the answer in the provided document.

# %%
def ask_question(question):
    """
    Ask a question about the Machine Learning PDF.

    The function:
    1. Retrieves relevant chunks from FAISS
    2. Creates context from those chunks
    3. Builds a RAG prompt
    4. Sends the prompt to Gemini
    5. Returns the final answer
    """

    # Step 1: Retrieve relevant chunks
    retrieved_docs = vector_store.similarity_search(
        question,
        k=3
    )

    # Step 2: Combine retrieved chunks into context
    context = "\n\n".join(
        doc.page_content for doc in retrieved_docs
    )

    # Step 3: Create the RAG prompt
    prompt = f"""
    You are a helpful Machine Learning assistant.

    Answer the user's question using ONLY the information
    provided in the context below.

    If the answer cannot be found in the context, say:
    "I could not find the answer in the provided document."

    Context:
    {context}

    Question:
    {question}

    Answer:
    """

    # Step 4: Send prompt to Gemini
    response = llm.invoke(prompt)

    # Step 5: Return the clean text response
    return response.text

# %%
question = "Machine learning: what and why?"

answer = ask_question(question)

print("Question:", question)
print("\nAnswer:", answer)
# Out:
# /home/nineleaps/mini-rag-chatbot/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Question: Machine learning: what and why?
#
# Answer: Based on the provided context, machine learning provides automated methods of data analysis to address the deluge of data in the era of big data.
#
# Specifically, machine learning is defined as a set of methods that can automatically detect patterns in data, and then use those uncovered patterns to predict future data, or to perform other kinds of decision making under uncertainty (such as planning how to collect more data).

# %%
# Set the Gemini API key securely
# The key will not be displayed or saved in the notebook.

import os
from getpass import getpass

if not os.getenv("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = getpass(
        "Enter your Gemini API key: "
    )

print("Gemini API key configured successfully!")
# Out:
# Enter your Gemini API key:  ········
# Gemini API key configured successfully!
